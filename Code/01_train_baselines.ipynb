# %% [markdown]
# # Train Baselines
#
# Notebook-first workflow for grid search, best-config selection, and final baseline training on the `train` and `retrain` splits.

# %%
from pathlib import Path

import json
import matplotlib.pyplot as plt

from notebook_workflows import (
    build_small_search_space,
    rank_search_results,
    results_to_dataframe,
    run_training_notebook_workflow,
)

# %%
# Centralized config
DATASET = "cifar10"  # or "mufac"
RUN_TRAIN = True
RUN_RETRAIN = False
USE_WANDB = True
SMOKE_MODE = False
REUSE_EXISTING_TRAIN_GRID = True
SEED = 0
NUM_BANK_SEEDS = 3
EPOCHS = 40
DEVICE = "auto"
MOMENTUM = 0.9
IMAGE_SIZE = 32 if DATASET == "cifar10" else 224
CLASS_WEIGHTING = "auto"

CHECKPOINT_DIR = Path("checkpoints")
RESULTS_DIR = Path("results") / "grid_search"
DATA_ROOT = None
TASK_MANIFEST = None
SAMPLES_CSV = None

SEARCH_SPACE = build_small_search_space(DATASET)

# %%
#!pip install "wandb==0.25.0"

# %%
# !wandb login
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from C:\Users\inzag\_netrc.
# wandb: Currently logged in as: inmdev (inmdev-university-of-british-columbia) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin

# %%
training_outputs = run_training_notebook_workflow(
    dataset=DATASET,
    run_train=RUN_TRAIN,
    run_retrain=RUN_RETRAIN,
    search_space=SEARCH_SPACE,
    epochs=EPOCHS,
    seed=SEED,
    num_bank_seeds=NUM_BANK_SEEDS,
    use_wandb=USE_WANDB,
    smoke_mode=SMOKE_MODE,
    checkpoint_dir=CHECKPOINT_DIR,
    results_dir=RESULTS_DIR,
    data_root=DATA_ROOT,
    task_manifest=TASK_MANIFEST,
    samples_csv=SAMPLES_CSV,
    momentum=MOMENTUM,
    image_size=IMAGE_SIZE,
    class_weighting=CLASS_WEIGHTING,
    device=DEVICE,
    reuse_existing_train_grid=REUSE_EXISTING_TRAIN_GRID,
)

training_outputs
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from C:\Users\inzag\_netrc.
# wandb: Currently logged in as: inmdev (inmdev-university-of-british-columbia) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>c:\Users\inzag\Documents\GitHub\550-project\CPSC550_Project\Code\wandb\run-20260408_011152-du8yc7qb</code>
# Syncing run <strong><a href='https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning/runs/du8yc7qb' target="_blank">grid_search_train_cfg01</a></strong> to <a href='https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning' target="_blank">https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning</a>
#  View run at <a href='https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning/runs/du8yc7qb' target="_blank">https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning/runs/du8yc7qb</a>
# Epoch 1/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 2/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 3/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 4/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 5/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 6/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 7/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 8/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 9/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 10/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 11/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 12/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 13/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 14/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 15/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 16/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 17/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 18/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 19/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 20/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 21/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 22/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 23/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 24/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 25/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 26/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 27/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 28/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 29/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 30/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 31/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 32/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 33/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 34/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 35/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 36/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 37/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 38/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 39/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 40/40:   0%|          | 0/52 [00:00<?, ?it/s]
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>train_loss</td><td>█▇▆▆▅▅▄▄▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▂▂▅▁▂▆▁▅▇▇▅▆▆▇▇▆▇███████████████████████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>40</td></tr><tr><td>train_loss</td><td>0.00023</td></tr><tr><td>val_accuracy</td><td>0.4104</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">grid_search_train_cfg01</strong> at: <a href='https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning/runs/du8yc7qb' target="_blank">https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning/runs/du8yc7qb</a><br> View project at: <a href='https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning' target="_blank">https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20260408_011152-du8yc7qb\logs</code>
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>c:\Users\inzag\Documents\GitHub\550-project\CPSC550_Project\Code\wandb\run-20260408_012508-veyehawm</code>
# Syncing run <strong><a href='https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning/runs/veyehawm' target="_blank">grid_search_train_cfg02</a></strong> to <a href='https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning' target="_blank">https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning</a>
#  View run at <a href='https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning/runs/veyehawm' target="_blank">https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning/runs/veyehawm</a>
# Epoch 1/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 2/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 3/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 4/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 5/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 6/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 7/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 8/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 9/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 10/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 11/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 12/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 13/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 14/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 15/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 16/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 17/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 18/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 19/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 20/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 21/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 22/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 23/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 24/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 25/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 26/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 27/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 28/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 29/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 30/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 31/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 32/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 33/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 34/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 35/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 36/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 37/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 38/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 39/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 40/40:   0%|          | 0/52 [00:00<?, ?it/s]
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>train_loss</td><td>█▇▆▆▅▅▄▄▃▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▃▃▄▁▃▅▁▆▆▄▇▄▆█▇█████████████████████████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>40</td></tr><tr><td>train_loss</td><td>0.00056</td></tr><tr><td>val_accuracy</td><td>0.41453</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">grid_search_train_cfg02</strong> at: <a href='https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning/runs/veyehawm' target="_blank">https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning/runs/veyehawm</a><br> View project at: <a href='https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning' target="_blank">https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20260408_012508-veyehawm\logs</code>
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>c:\Users\inzag\Documents\GitHub\550-project\CPSC550_Project\Code\wandb\run-20260408_013746-2d46mvoh</code>
# Syncing run <strong><a href='https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning/runs/2d46mvoh' target="_blank">grid_search_train_cfg03</a></strong> to <a href='https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning' target="_blank">https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning</a>
#  View run at <a href='https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning/runs/2d46mvoh' target="_blank">https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning/runs/2d46mvoh</a>
# Epoch 1/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 2/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 3/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 4/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 5/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 6/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 7/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 8/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 9/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 10/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 11/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 12/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 13/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 14/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 15/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 16/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 17/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 18/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 19/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 20/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 21/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 22/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 23/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 24/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 25/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 26/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 27/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 28/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 29/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 30/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 31/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 32/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 33/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 34/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 35/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 36/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 37/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 38/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 39/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 40/40:   0%|          | 0/52 [00:00<?, ?it/s]
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>train_loss</td><td>█▇▆▆▅▅▄▄▃▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▂▃▅▁▄▇▄▄▄▆▆▄▇▆▅█████████████████████████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>40</td></tr><tr><td>train_loss</td><td>0.00113</td></tr><tr><td>val_accuracy</td><td>0.41288</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">grid_search_train_cfg03</strong> at: <a href='https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning/runs/2d46mvoh' target="_blank">https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning/runs/2d46mvoh</a><br> View project at: <a href='https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning' target="_blank">https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20260408_013746-2d46mvoh\logs</code>
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>c:\Users\inzag\Documents\GitHub\550-project\CPSC550_Project\Code\wandb\run-20260408_015022-ya851ouo</code>
# Syncing run <strong><a href='https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning/runs/ya851ouo' target="_blank">grid_search_train_cfg04</a></strong> to <a href='https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning' target="_blank">https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning</a>
#  View run at <a href='https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning/runs/ya851ouo' target="_blank">https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning/runs/ya851ouo</a>
# Epoch 1/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 2/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 3/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 4/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 5/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 6/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 7/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 8/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 9/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 10/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 11/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 12/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 13/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 14/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 15/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 16/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 17/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 18/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 19/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 20/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 21/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 22/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 23/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 24/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 25/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 26/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 27/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 28/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 29/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 30/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 31/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 32/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 33/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 34/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 35/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 36/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 37/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 38/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 39/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 40/40:   0%|          | 0/52 [00:00<?, ?it/s]
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>train_loss</td><td>█▆▆▆▆▆▆▅▅▅▅▄▄▄▄▄▃▃▃▂▂▂▁▁▁▁▁▂▂▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▃▂▂▄▄▂▂▂▇▆▇▆▇▇▆▆▇▆▆▇▇▇▇▇▇▇▇▅█▇█████████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>40</td></tr><tr><td>train_loss</td><td>0.00034</td></tr><tr><td>val_accuracy</td><td>0.45995</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">grid_search_train_cfg04</strong> at: <a href='https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning/runs/ya851ouo' target="_blank">https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning/runs/ya851ouo</a><br> View project at: <a href='https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning' target="_blank">https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20260408_015022-ya851ouo\logs</code>
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>c:\Users\inzag\Documents\GitHub\550-project\CPSC550_Project\Code\wandb\run-20260408_020259-g2j2sv56</code>
# Syncing run <strong><a href='https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning/runs/g2j2sv56' target="_blank">grid_search_train_cfg05</a></strong> to <a href='https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning' target="_blank">https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning</a>
#  View run at <a href='https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning/runs/g2j2sv56' target="_blank">https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning/runs/g2j2sv56</a>
# Epoch 1/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 2/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 3/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 4/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 5/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 6/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 7/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 8/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 9/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 10/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 11/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 12/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 13/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 14/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 15/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 16/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 17/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 18/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 19/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 20/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 21/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 22/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 23/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 24/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 25/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 26/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 27/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 28/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 29/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 30/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 31/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 32/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 33/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 34/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 35/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 36/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 37/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 38/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 39/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 40/40:   0%|          | 0/52 [00:00<?, ?it/s]
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>train_loss</td><td>█▇▇▆▆▆▆▅▅▅▅▄▄▄▄▃▃▃▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▂▂▄▄▄▄▄▁▅▇▆▇▆▇▆▆▄▇▅▇▇▇▇▆▆█▇▇████████████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>40</td></tr><tr><td>train_loss</td><td>0.00079</td></tr><tr><td>val_accuracy</td><td>0.44756</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">grid_search_train_cfg05</strong> at: <a href='https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning/runs/g2j2sv56' target="_blank">https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning/runs/g2j2sv56</a><br> View project at: <a href='https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning' target="_blank">https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20260408_020259-g2j2sv56\logs</code>
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>c:\Users\inzag\Documents\GitHub\550-project\CPSC550_Project\Code\wandb\run-20260408_021537-ejdb1j69</code>
# Syncing run <strong><a href='https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning/runs/ejdb1j69' target="_blank">grid_search_train_cfg06</a></strong> to <a href='https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning' target="_blank">https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning</a>
#  View run at <a href='https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning/runs/ejdb1j69' target="_blank">https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning/runs/ejdb1j69</a>
# Epoch 1/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 2/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 3/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 4/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 5/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 6/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 7/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 8/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 9/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 10/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 11/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 12/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 13/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 14/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 15/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 16/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 17/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 18/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 19/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 20/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 21/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 22/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 23/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 24/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 25/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 26/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 27/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 28/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 29/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 30/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 31/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 32/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 33/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 34/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 35/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 36/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 37/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 38/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 39/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 40/40:   0%|          | 0/52 [00:00<?, ?it/s]
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>train_loss</td><td>█▆▆▆▆▆▆▅▅▅▅▄▄▄▄▄▃▃▃▃▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▄▂▃▃▃▅▁▂▆▆▇▄▇▇▆▆▇▅▇▅▇▇▆▇█▅▇▇███████████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>40</td></tr><tr><td>train_loss</td><td>0.00222</td></tr><tr><td>val_accuracy</td><td>0.45995</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">grid_search_train_cfg06</strong> at: <a href='https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning/runs/ejdb1j69' target="_blank">https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning/runs/ejdb1j69</a><br> View project at: <a href='https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning' target="_blank">https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20260408_021537-ejdb1j69\logs</code>
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>c:\Users\inzag\Documents\GitHub\550-project\CPSC550_Project\Code\wandb\run-20260408_022815-zmfs850x</code>
# Syncing run <strong><a href='https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning/runs/zmfs850x' target="_blank">grid_search_train_cfg07</a></strong> to <a href='https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning' target="_blank">https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning</a>
#  View run at <a href='https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning/runs/zmfs850x' target="_blank">https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning/runs/zmfs850x</a>
# Epoch 1/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 2/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 3/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 4/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 5/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 6/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 7/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 8/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 9/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 10/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 11/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 12/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 13/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 14/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 15/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 16/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 17/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 18/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 19/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 20/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 21/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 22/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 23/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 24/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 25/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 26/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 27/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 28/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 29/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 30/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 31/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 32/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 33/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 34/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 35/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 36/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 37/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 38/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 39/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 40/40:   0%|          | 0/52 [00:00<?, ?it/s]
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>train_loss</td><td>█▆▆▆▆▆▆▆▆▅▅▅▅▅▅▄▄▄▄▄▄▃▃▃▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▃▄▁▂▃▂▄▃▄▄▅▂▆▆▄▃▃▁█▃▇▇▇▆▅▇▇▆▆▆█▇▇▇▇▇████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>40</td></tr><tr><td>train_loss</td><td>0.00067</td></tr><tr><td>val_accuracy</td><td>0.43187</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">grid_search_train_cfg07</strong> at: <a href='https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning/runs/zmfs850x' target="_blank">https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning/runs/zmfs850x</a><br> View project at: <a href='https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning' target="_blank">https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20260408_022815-zmfs850x\logs</code>
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>c:\Users\inzag\Documents\GitHub\550-project\CPSC550_Project\Code\wandb\run-20260408_024054-5kw7uwhc</code>
# Syncing run <strong><a href='https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning/runs/5kw7uwhc' target="_blank">grid_search_train_cfg08</a></strong> to <a href='https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning' target="_blank">https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning</a>
#  View run at <a href='https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning/runs/5kw7uwhc' target="_blank">https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning/runs/5kw7uwhc</a>
# Epoch 1/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 2/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 3/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 4/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 5/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 6/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 7/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 8/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 9/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 10/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 11/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 12/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 13/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 14/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 15/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 16/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 17/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 18/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 19/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 20/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 21/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 22/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 23/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 24/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 25/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 26/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 27/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 28/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 29/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 30/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 31/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 32/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 33/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 34/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 35/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 36/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 37/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 38/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 39/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 40/40:   0%|          | 0/52 [00:00<?, ?it/s]
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>train_loss</td><td>█▆▆▆▆▆▆▆▆▅▅▅▅▅▅▄▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▂▄▂▂▄▂▄▄▃▂▂▁▄▆▅▄▄▇▇▇▇▇▆▆▇▆▆▇▆▆▇█▇██▇▇█▇▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>40</td></tr><tr><td>train_loss</td><td>0.26022</td></tr><tr><td>val_accuracy</td><td>0.36746</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">grid_search_train_cfg08</strong> at: <a href='https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning/runs/5kw7uwhc' target="_blank">https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning/runs/5kw7uwhc</a><br> View project at: <a href='https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning' target="_blank">https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20260408_024054-5kw7uwhc\logs</code>
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>c:\Users\inzag\Documents\GitHub\550-project\CPSC550_Project\Code\wandb\run-20260408_025331-uql6s96l</code>
# Syncing run <strong><a href='https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning/runs/uql6s96l' target="_blank">grid_search_train_cfg09</a></strong> to <a href='https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning' target="_blank">https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning</a>
#  View run at <a href='https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning/runs/uql6s96l' target="_blank">https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning/runs/uql6s96l</a>
# Epoch 1/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 2/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 3/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 4/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 5/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 6/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 7/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 8/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 9/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 10/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 11/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 12/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 13/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 14/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 15/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 16/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 17/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 18/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 19/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 20/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 21/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 22/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 23/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 24/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 25/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 26/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 27/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 28/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 29/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 30/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 31/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 32/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 33/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 34/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 35/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 36/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 37/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 38/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 39/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 40/40:   0%|          | 0/52 [00:00<?, ?it/s]
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>train_loss</td><td>█▆▆▆▆▆▆▆▆▅▅▅▅▄▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂▂▁▁▁▁▂▂▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▄▂▄▄▄▄▃▁▂▆▆▆▆▇▅▃▇▆▆█▄█▄▇▇▇▇█▆▆█▇▇▆▆▇▇▇█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>40</td></tr><tr><td>train_loss</td><td>0.02354</td></tr><tr><td>val_accuracy</td><td>0.41536</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">grid_search_train_cfg09</strong> at: <a href='https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning/runs/uql6s96l' target="_blank">https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning/runs/uql6s96l</a><br> View project at: <a href='https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning' target="_blank">https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20260408_025331-uql6s96l\logs</code>
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>c:\Users\inzag\Documents\GitHub\550-project\CPSC550_Project\Code\wandb\run-20260408_030610-141c7nxs</code>
# Syncing run <strong><a href='https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning/runs/141c7nxs' target="_blank">baseline_train</a></strong> to <a href='https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning' target="_blank">https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning</a>
#  View run at <a href='https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning/runs/141c7nxs' target="_blank">https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning/runs/141c7nxs</a>
# Epoch 1/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 2/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 3/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 4/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 5/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 6/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 7/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 8/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 9/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 10/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 11/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 12/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 13/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 14/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 15/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 16/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 17/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 18/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 19/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 20/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 21/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 22/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 23/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 24/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 25/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 26/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 27/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 28/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 29/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 30/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 31/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 32/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 33/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 34/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 35/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 36/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 37/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 38/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 39/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 40/40:   0%|          | 0/52 [00:00<?, ?it/s]
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>train_loss</td><td>█▇▇▆▆▆▆▅▅▅▅▄▄▄▄▃▃▃▃▂▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▂▄▄▂▂▅▃▆▃▆▇▇▇█▄▆▆▅▅▇▇▆▇▇▇██████████████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>40</td></tr><tr><td>train_loss</td><td>0.00027</td></tr><tr><td>val_accuracy</td><td>0.42527</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">baseline_train</strong> at: <a href='https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning/runs/141c7nxs' target="_blank">https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning/runs/141c7nxs</a><br> View project at: <a href='https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning' target="_blank">https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20260408_030610-141c7nxs\logs</code>
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>c:\Users\inzag\Documents\GitHub\550-project\CPSC550_Project\Code\wandb\run-20260408_031849-qovnwocr</code>
# Syncing run <strong><a href='https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning/runs/qovnwocr' target="_blank">baseline_train</a></strong> to <a href='https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning' target="_blank">https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning</a>
#  View run at <a href='https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning/runs/qovnwocr' target="_blank">https://wandb.ai/inmdev-university-of-british-columbia/machine-unlearning/runs/qovnwocr</a>
# Epoch 1/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 2/40:   0%|          | 0/52 [00:00<?, ?it/s]
# Epoch 3/40:   0%|          | 0/52 [00:00<?, ?it/s]
# ...
#       'runtime_seconds': 669.1108630999952,
#       'best_val_accuracy': 0.4203137902559868,
#       'final_val_accuracy': 0.4186622625928984,
#       'checkpoint_path': 'checkpoints\\mufac\\forget_mixed\\baseline_retrain\\seed_0.pth',
#       'epochs_logged': [{'epoch': 1.0,
#         'train_loss': 2.529739571910007,
#         'val_accuracy': 0.01981833195706028},
#        {'epoch': 2.0,
#         'train_loss': 2.123357099655024,
#         'val_accuracy': 0.05615194054500413},
#        {'epoch': 3.0,
#         'train_loss': 2.062695862271042,
#         'val_accuracy': 0.09413707679603633},
#        {'epoch': 4.0,
#         'train_loss': 2.0372299190359535,
#         'val_accuracy': 0.1874483897605285},
#        {'epoch': 5.0,
#         'train_loss': 2.018158734217545,
#         'val_accuracy': 0.2402972749793559},
#        {'epoch': 6.0,
#         'train_loss': 1.968164196769921,
#         'val_accuracy': 0.22378199834847234},
#        {'epoch': 7.0,
#         'train_loss': 1.9117915897919453,
#         'val_accuracy': 0.1635012386457473},
#        {'epoch': 8.0,
#         'train_loss': 1.8166806590979592,
#         'val_accuracy': 0.04541701073492981},
#        {'epoch': 9.0,
#         'train_loss': 1.653894323371532,
#         'val_accuracy': 0.0685383980181668},
#        {'epoch': 10.0,
#         'train_loss': 1.545587754398688,
#         'val_accuracy': 0.314616019818332},
#        {'epoch': 11.0,
#         'train_loss': 1.467822631752433,
#         'val_accuracy': 0.33360858794384807},
#        {'epoch': 12.0,
#         'train_loss': 1.3890676557230734,
#         'val_accuracy': 0.3550784475639967},
#        {'epoch': 13.0,
#         'train_loss': 1.277865189906207,
#         'val_accuracy': 0.23864574731626756},
#        {'epoch': 14.0,
#         'train_loss': 1.2141789624556807,
#         'val_accuracy': 0.2526837324525186},
#        {'epoch': 15.0,
#         'train_loss': 1.1016675950422148,
#         'val_accuracy': 0.3179190751445087},
#        {'epoch': 16.0,
#         'train_loss': 0.9620118240584425,
#         'val_accuracy': 0.3104872006606111},
#        {'epoch': 17.0,
#         'train_loss': 0.9279134674068952,
#         'val_accuracy': 0.30800990916597853},
#        {'epoch': 18.0,
#         'train_loss': 0.8249372436074104,
#         'val_accuracy': 0.3393889347646573},
#        {'epoch': 19.0,
#         'train_loss': 0.7125781835409566,
#         'val_accuracy': 0.2989265070189926},
#        {'epoch': 20.0,
#         'train_loss': 0.4957461069034486,
#         'val_accuracy': 0.3236994219653179},
#        {'epoch': 21.0,
#         'train_loss': 0.3634168889225979,
#         'val_accuracy': 0.38893476465730803},
#        {'epoch': 22.0,
#         'train_loss': 0.23289390126808887,
#         'val_accuracy': 0.40214698596201487},
#        {'epoch': 23.0,
#         'train_loss': 0.31414701536432416,
#         'val_accuracy': 0.3592072667217176},
#        {'epoch': 24.0,
#         'train_loss': 0.21816053524706577,
#         'val_accuracy': 0.3823286540049546},
#        {'epoch': 25.0,
#         'train_loss': 0.1812395672776618,
#         'val_accuracy': 0.37572254335260113},
#        {'epoch': 26.0,
#         'train_loss': 0.2391261383010912,
#         'val_accuracy': 0.35342691990090835},
#        {'epoch': 27.0,
#         'train_loss': 0.27550234966099135,
#         'val_accuracy': 0.28075970272502065},
#        {'epoch': 28.0,
#         'train_loss': 0.2371472423071659,
#         'val_accuracy': 0.29644921552436004},
#        {'epoch': 29.0,
#         'train_loss': 0.10090549672287814,
#         'val_accuracy': 0.37241948802642444},
#        {'epoch': 30.0,
#         'train_loss': 0.03302307526857344,
#         'val_accuracy': 0.3699421965317919},
#        {'epoch': 31.0,
#         'train_loss': 0.01132436282220837,
#         'val_accuracy': 0.41453344343517756},
#        {'epoch': 32.0,
#         'train_loss': 0.004547057133569247,
#         'val_accuracy': 0.41453344343517756},
#        {'epoch': 33.0,
#         'train_loss': 0.002382417432730856,
#         'val_accuracy': 0.4203137902559868},
#        {'epoch': 34.0,
#         'train_loss': 0.0030421411062482697,
#         'val_accuracy': 0.402972749793559},
#        {'epoch': 35.0,
#         'train_loss': 0.000779549507794758,
#         'val_accuracy': 0.4071015689512799},
#        {'epoch': 36.0,
#         'train_loss': 0.0005630434180407308,
#         'val_accuracy': 0.41288191577208916},
#        {'epoch': 37.0,
#         'train_loss': 0.00048062345933261677,
#         'val_accuracy': 0.41288191577208916},
#        {'epoch': 38.0,
#         'train_loss': 0.0004416920605184843,
#         'val_accuracy': 0.4203137902559868},
#        {'epoch': 39.0,
#         'train_loss': 0.0004057075184631751,
#         'val_accuracy': 0.41370767960363336},
#        {'epoch': 40.0,
#         'train_loss': 0.00036776632675593633,
#         'val_accuracy': 0.4186622625928984}],
#       'image_size': 224,
#       'selection_mode': 'reuse_train_best',
#       'selected_on_split': 'train',
#       'applied_to_split': 'retrain',
#       'source_best_config_path': 'results\\grid_search\\mufac\\train\\best_config.json'},
#      {'dataset': 'mufac',
#       'task_id': 'forget_mixed',
#       'run_name': 'baseline_retrain',
#       'train_split': 'retrain',
#       'seed': 1,
#       'epochs': 40,
#       'batch_size': 128,
#       'learning_rate': 0.05,
#       'momentum': 0.9,
#       'weight_decay': 0.0001,
#       'class_weighting': 'inverse_freq',
#       'num_classes': 8,
#       'label_to_index': {'a': 0,
#        'b': 1,
#        'c': 2,
#        'd': 3,
#        'e': 4,
#        'f': 5,
#        'g': 6,
#        'h': 7},
#       'class_names': ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h'],
#       'runtime_seconds': 669.5519262000016,
#       'best_val_accuracy': 0.4186622625928984,
#       'final_val_accuracy': 0.4161849710982659,
#       'checkpoint_path': 'checkpoints\\mufac\\forget_mixed\\baseline_retrain\\seed_1.pth',
#       'epochs_logged': [{'epoch': 1.0,
#         'train_loss': 2.66668346261216,
#         'val_accuracy': 0.2023121387283237},
#        {'epoch': 2.0,
#         'train_loss': 2.1051479100021244,
#         'val_accuracy': 0.10569777043765483},
#        {'epoch': 3.0,
#         'train_loss': 2.072584352367367,
#         'val_accuracy': 0.06688687035507845},
#        {'epoch': 4.0,
#         'train_loss': 2.0347655700924827,
#         'val_accuracy': 0.18084227910817507},
#        {'epoch': 5.0,
#         'train_loss': 1.9971792991166317,
#         'val_accuracy': 0.042939719240297276},
#        {'epoch': 6.0,
#         'train_loss': 1.9290259031059842,
#         'val_accuracy': 0.19735755573905864},
#        {'epoch': 7.0,
#         'train_loss': 1.8082887445414042,
#         'val_accuracy': 0.2939719240297275},
#        {'epoch': 8.0,
#         'train_loss': 1.663333449287494,
#         'val_accuracy': 0.2444260941370768},
#        {'epoch': 9.0,
#         'train_loss': 1.5696497336288886,
#         'val_accuracy': 0.14781172584640792},
#        {'epoch': 10.0,
#         'train_loss': 1.4572534641513732,
#         'val_accuracy': 0.2336911643270025},
#        {'epoch': 11.0,
#         'train_loss': 1.35797785511441,
#         'val_accuracy': 0.35755573905862925},
#        {'epoch': 12.0,
#         'train_loss': 1.2961273662243724,
#         'val_accuracy': 0.2815854665565648},
#        {'epoch': 13.0,
#         'train_loss': 1.1569389837578488,
#         'val_accuracy': 0.38398018166804293},
#        {'epoch': 14.0,
#         'train_loss': 1.0103052402221966,
#         'val_accuracy': 0.08918249380677126},
#        {'epoch': 15.0,
#         'train_loss': 0.9287746552380528,
#         'val_accuracy': 0.27250206440957886},
#        {'epoch': 16.0,
#         'train_loss': 0.816402043378378,
#         'val_accuracy': 0.3063583815028902},
#        {'epoch': 17.0,
#         'train_loss': 0.7541863832977432,
#         'val_accuracy': 0.3014037985136251},
#        {'epoch': 18.0,
#         'train_loss': 0.49638466724428226,
#         'val_accuracy': 0.3063583815028902},
#        {'epoch': 19.0,
#         'train_loss': 0.3035266250268381,
#         'val_accuracy': 0.28901734104046245},
#        {'epoch': 20.0,
#         'train_loss': 0.30495927947275003,
#         'val_accuracy': 0.3385631709331131},
#        {'epoch': 21.0,
#         'train_loss': 0.3236125417058877,
#         'val_accuracy': 0.3220478943022296},
#        {'epoch': 22.0,
#         'train_loss': 0.4036975893152514,
#         'val_accuracy': 0.32947976878612717},
#        {'epoch': 23.0,
#         'train_loss': 0.21438205416124673,
#         'val_accuracy': 0.30388109000825764},
#        {'epoch': 24.0,
#         'train_loss': 0.10603413856675677,
#         'val_accuracy': 0.4186622625928984},
#        {'epoch': 25.0,
#         'train_loss': 0.05485263812440481,
#         'val_accuracy': 0.4071015689512799},
#        {'epoch': 26.0,
#         'train_loss': 0.013749496024969223,
#         'val_accuracy': 0.40957886044591246},
#        {'epoch': 27.0,
#         'train_loss': 0.0032444363214008255,
#         'val_accuracy': 0.4079273327828241},
#        {'epoch': 28.0,
#         'train_loss': 0.001268852378653985,
#         'val_accuracy': 0.40957886044591246},
#        {'epoch': 29.0,
#         'train_loss': 0.0008184192816243404,
#         'val_accuracy': 0.41701073492981006},
#        {'epoch': 30.0,
#         'train_loss': 0.0005842576371237269,
#         'val_accuracy': 0.412056151940545},
#        {'epoch': 31.0,
#         'train_loss': 0.0005076952740594374,
#         'val_accuracy': 0.40957886044591246},
#        {'epoch': 32.0,
#         'train_loss': 0.0004879412932935947,
#         'val_accuracy': 0.41288191577208916},
#        {'epoch': 33.0,
#         'train_loss': 0.00040351177212705186,
#         'val_accuracy': 0.412056151940545},
#        {'epoch': 34.0,
#         'train_loss': 0.0003987831488132601,
#         'val_accuracy': 0.4153592072667217},
#        {'epoch': 35.0,
#         'train_loss': 0.00035514034622247234,
#         'val_accuracy': 0.41453344343517756},
#        {'epoch': 36.0,
#         'train_loss': 0.0003732498895169493,
#         'val_accuracy': 0.40957886044591246},
#        {'epoch': 37.0,
#         'train_loss': 0.00031745901369813976,
#         'val_accuracy': 0.41370767960363336},
#        {'epoch': 38.0,
#         'train_loss': 0.0003224296460814497,
#         'val_accuracy': 0.41288191577208916},
#        {'epoch': 39.0,
#         'train_loss': 0.00027106989428217834,
#         'val_accuracy': 0.41453344343517756},
#        {'epoch': 40.0,
#         'train_loss': 0.00027295530524041407,
#         'val_accuracy': 0.4161849710982659}],
#       'image_size': 224,
#       'selection_mode': 'reuse_train_best',
#       'selected_on_split': 'train',
#       'applied_to_split': 'retrain',
#       'source_best_config_path': 'results\\grid_search\\mufac\\train\\best_config.json'},
#      {'dataset': 'mufac',
#       'task_id': 'forget_mixed',
#       'run_name': 'baseline_retrain',
#       'train_split': 'retrain',
#       'seed': 2,
#       'epochs': 40,
#       'batch_size': 128,
#       'learning_rate': 0.05,
#       'momentum': 0.9,
#       'weight_decay': 0.0001,
#       'class_weighting': 'inverse_freq',
#       'num_classes': 8,
#       'label_to_index': {'a': 0,
#        'b': 1,
#        'c': 2,
#        'd': 3,
#        'e': 4,
#        'f': 5,
#        'g': 6,
#        'h': 7},
#       'class_names': ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h'],
#       'runtime_seconds': 670.1560109999991,
#       'best_val_accuracy': 0.42196531791907516,
#       'final_val_accuracy': 0.41701073492981006,
#       'checkpoint_path': 'checkpoints\\mufac\\forget_mixed\\baseline_retrain\\seed_2.pth',
#       'epochs_logged': [{'epoch': 1.0,
#         'train_loss': 3.017660366817843,
#         'val_accuracy': 0.1907514450867052},
#        {'epoch': 2.0,
#         'train_loss': 2.099414606571529,
#         'val_accuracy': 0.21056977704376548},
#        {'epoch': 3.0,
#         'train_loss': 2.0646398417066583,
#         'val_accuracy': 0.21056977704376548},
#        {'epoch': 4.0,
#         'train_loss': 2.041773170046379,
#         'val_accuracy': 0.1874483897605285},
#        {'epoch': 5.0,
#         'train_loss': 1.9731660003542817,
#         'val_accuracy': 0.09826589595375723},
#        {'epoch': 6.0,
#         'train_loss': 1.9064927661145536,
#         'val_accuracy': 0.037985136251032205},
#        {'epoch': 7.0,
#         'train_loss': 1.804925165464681,
#         'val_accuracy': 0.23947151114781173},
#        {'epoch': 8.0,
#         'train_loss': 1.7024655989924597,
#         'val_accuracy': 0.2972749793559042},
#        {'epoch': 9.0,
#         'train_loss': 1.6191880480128082,
#         'val_accuracy': 0.32039636663914123},
#        {'epoch': 10.0,
#         'train_loss': 1.527387356824391,
#         'val_accuracy': 0.28819157720891825},
#        {'epoch': 11.0,
#         'train_loss': 1.4229359093269098,
#         'val_accuracy': 0.305532617671346},
#        {'epoch': 12.0,
#         'train_loss': 1.3481721906217956,
#         'val_accuracy': 0.21139554087530965},
#        {'epoch': 13.0,
#         'train_loss': 1.2776522635585157,
#         'val_accuracy': 0.3856317093311313},
#        {'epoch': 14.0,
#         'train_loss': 1.1643093498818489,
#         'val_accuracy': 0.3625103220478943},
#        {'epoch': 15.0,
#         'train_loss': 1.052934767141203,
#         'val_accuracy': 0.3236994219653179},
#        {'epoch': 16.0,
#         'train_loss': 0.9442079443331806,
#         'val_accuracy': 0.3344343517753922},
#        {'epoch': 17.0,
#         'train_loss': 0.8944699072523031,
#         'val_accuracy': 0.3815028901734104},
#        {'epoch': 18.0,
#         'train_loss': 0.7634129819147615,
#         'val_accuracy': 0.36416184971098264},
#        {'epoch': 19.0,
#         'train_loss': 0.5587894976594698,
#         'val_accuracy': 0.3137902559867878},
#        {'epoch': 20.0,
#         'train_loss': 0.5073400803785344,
#         'val_accuracy': 0.2947976878612717},
#        {'epoch': 21.0,
#         'train_loss': 0.4650338458426716,
#         'val_accuracy': 0.37654830718414534},
#        {'epoch': 22.0,
#         'train_loss': 0.32895800239348927,
#         'val_accuracy': 0.38893476465730803},
#        {'epoch': 23.0,
#         'train_loss': 0.14430092881958545,
#         'val_accuracy': 0.3872832369942196},
#        {'epoch': 24.0,
#         'train_loss': 0.06714810543098824,
#         'val_accuracy': 0.3996696944673823},
#        {'epoch': 25.0,
#         'train_loss': 0.025854988138516943,
#         'val_accuracy': 0.38810900082576383},
#        {'epoch': 26.0,
#         'train_loss': 0.016456544163680226,
#         'val_accuracy': 0.3790255986787779},
#        {'epoch': 27.0,
#         'train_loss': 0.012629105155488905,
#         'val_accuracy': 0.4037985136251032},
#        {'epoch': 28.0,
#         'train_loss': 0.004486172785804509,
#         'val_accuracy': 0.40957886044591246},
#        {'epoch': 29.0,
#         'train_loss': 0.0016347511549000683,
#         'val_accuracy': 0.40957886044591246},
#        {'epoch': 30.0,
#         'train_loss': 0.0009056682890323796,
#         'val_accuracy': 0.4087530966143683},
#        {'epoch': 31.0,
#         'train_loss': 0.0005701247123286873,
#         'val_accuracy': 0.4203137902559868},
#        {'epoch': 32.0,
#         'train_loss': 0.0005753415946484963,
#         'val_accuracy': 0.41783649876135426},
#        {'epoch': 33.0,
#         'train_loss': 0.0005114381095586063,
#         'val_accuracy': 0.42196531791907516},
#        {'epoch': 34.0,
#         'train_loss': 0.0004763111464525207,
#         'val_accuracy': 0.41288191577208916},
#        {'epoch': 35.0,
#         'train_loss': 0.00041188958508792237,
#         'val_accuracy': 0.41783649876135426},
#        {'epoch': 36.0,
#         'train_loss': 0.00039585469760805824,
#         'val_accuracy': 0.4203137902559868},
#        {'epoch': 37.0,
#         'train_loss': 0.0004175109134090947,
#         'val_accuracy': 0.4153592072667217},
#        {'epoch': 38.0,
#         'train_loss': 0.00036279484427380657,
#         'val_accuracy': 0.4194880264244426},
#        {'epoch': 39.0,
#         'train_loss': 0.0003379715731035131,
#         'val_accuracy': 0.4153592072667217},
#        {'epoch': 40.0,
#         'train_loss': 0.00035108361494985663,
#         'val_accuracy': 0.41701073492981006}],
#       'image_size': 224,
#       'selection_mode': 'reuse_train_best',
#       'selected_on_split': 'train',
#       'applied_to_split': 'retrain',
#       'source_best_config_path': 'results\\grid_search\\mufac\\train\\best_config.json'}],
#     'canonical_checkpoint': 'checkpoints\\mufac\\forget_mixed\\baseline_retrain\\seed_0.pth'}}}}

# %%
for split_name, split_outputs in training_outputs["splits"].items():
    print(f"\n=== {split_name.upper()} SUMMARY ===")
    selection = split_outputs["grid_search"]
    if selection.get("selection_mode") == "reuse_train_best":
        print("Retrain reused the train-selected best configuration.")
        print("Source split:", selection["source_split"])
        print("Source best config:", selection["source_best_config_path"])
    else:
        if selection.get("loaded_from_cache"):
            print("Loaded existing train grid-search results from:", selection["results_dir"])
            print("Cache match mode:", selection.get("cache_match"))
        ranked = rank_search_results(selection["results"])
        display(results_to_dataframe(ranked))
    print("Best config:")
    print(json.dumps(selection["best_result"], indent=2))
    print("Canonical checkpoint:", split_outputs["bank_training"]["canonical_checkpoint"])
# Out:
# === TRAIN SUMMARY ===
#    config_index train_split  batch_size  learning_rate  weight_decay  \
# 0             4       train         128           0.05        0.0001
# 1             6       train         128           0.05        0.0010
# 2             5       train         128           0.05        0.0005
# 3             9       train         128           0.08        0.0010
# 4             7       train         128           0.08        0.0001
# 5             8       train         128           0.08        0.0005
# 6             2       train         128           0.02        0.0005
# 7             3       train         128           0.02        0.0010
# 8             1       train         128           0.02        0.0001
#
#    best_val_accuracy  final_val_accuracy  runtime_seconds  \
# 0           0.464905            0.459950       748.550362
# 1           0.463254            0.459950       749.974853
# 2           0.459125            0.447564       749.186150
# 3           0.439306            0.415359       750.867844
# 4           0.435178            0.431874       749.218657
# 5           0.433526            0.367465       748.918978
# 6           0.430223            0.414533       748.841683
# 7           0.428571            0.412882       747.823755
# 8           0.423617            0.410405       784.813133
#
#                                      checkpoint_path  seed
# 0  checkpoints\mufac\forget_mixed\grid_search_tra...     0
# 1  checkpoints\mufac\forget_mixed\grid_search_tra...     0
# 2  checkpoints\mufac\forget_mixed\grid_search_tra...     0
# 3  checkpoints\mufac\forget_mixed\grid_search_tra...     0
# 4  checkpoints\mufac\forget_mixed\grid_search_tra...     0
# 5  checkpoints\mufac\forget_mixed\grid_search_tra...     0
# 6  checkpoints\mufac\forget_mixed\grid_search_tra...     0
# 7  checkpoints\mufac\forget_mixed\grid_search_tra...     0
# 8  checkpoints\mufac\forget_mixed\grid_search_tra...     0
# Best config:
# {
#   "config_index": 4,
#   "train_split": "train",
#   "batch_size": 128,
#   "learning_rate": 0.05,
#   "weight_decay": 0.0001,
#   "best_val_accuracy": 0.4649050371593724,
#   "final_val_accuracy": 0.4599504541701073,
#   "runtime_seconds": 748.5503622999968,
#   "checkpoint_path": "checkpoints\\mufac\\forget_mixed\\grid_search_train_cfg04\\seed_0.pth",
#   "seed": 0
# }
# Canonical checkpoint: checkpoints\mufac\forget_mixed\baseline_train\seed_0.pth
#
# === RETRAIN SUMMARY ===
# Retrain reused the train-selected best configuration.
# Source split: train
# Source best config: results\grid_search\mufac\train\best_config.json
# Best config:
# {
#   "config_index": 4,
#   "train_split": "train",
#   "batch_size": 128,
#   "learning_rate": 0.05,
#   "weight_decay": 0.0001,
#   "best_val_accuracy": 0.4649050371593724,
#   "final_val_accuracy": 0.4599504541701073,
#   "runtime_seconds": 748.5503622999968,
#   "checkpoint_path": "checkpoints\\mufac\\forget_mixed\\grid_search_train_cfg04\\seed_0.pth",
#   "seed": 0,
#   "epochs": 40
# }
# Canonical checkpoint: checkpoints\mufac\forget_mixed\baseline_retrain\seed_0.pth

# %%
for split_name, split_outputs in training_outputs["splits"].items():
    selection = split_outputs["grid_search"]
    if selection.get("selection_mode") == "reuse_train_best":
        print(f"Skipping validation-ranking plot for {split_name}: config reused from train.")
        continue
    ranked = rank_search_results(selection["results"])
    df = results_to_dataframe(ranked)
    if hasattr(df, "plot"):
        ax = df.plot(x="config_index", y="best_val_accuracy", kind="bar", title=f"{DATASET} {split_name} validation ranking")
        ax.set_ylabel("Best validation accuracy")
        plt.show()
# Out:
# Skipping validation-ranking plot for retrain: config reused from train.
